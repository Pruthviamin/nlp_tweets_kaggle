# %% [markdown]
# # NLP with Disaster Tweets

# %% [markdown]
# ### Predict which Tweets are about real disasters and which ones are not
#
# Twitter has become an important communication channel in times of emergency.
# The ubiquitousness of smartphones enables people to announce an emergency they’re observing in real-time. Because of this, more agencies are interested in programatically monitoring Twitter (i.e. disaster relief organizations and news agencies).
#
# But, it’s not always clear whether a person’s words are actually announcing a disaster. Take this example:
#
# The author explicitly uses the word “ABLAZE” but means it metaphorically. This is clear to a human right away, especially with the visual aid. But it’s less clear to a machine.
#
# In this competition, you’re challenged to build a machine learning model that predicts which Tweets are about real disasters and which one’s aren’t. You’ll have access to a dataset of 10,000 tweets that were hand classified. If this is your first time working on an NLP problem, we've created a quick tutorial to get you up and running.
#
# #### Columns
#
# - id - a unique identifier for each tweet
# - keyword - a particular keyword from the tweet (may be blank)
# - location - the location the tweet was sent from (may be blank)
# - text - the text of the tweet
# - target - in train.csv only, this denotes whether a tweet is about a real disaster (1) or not (0)
#
# #### What am I predicting?
#
# You are predicting whether a given tweet is about a real disaster or not. If so, predict a 1. If not, predict a 0.
#
# #### Evaluation Metric
#
# Submissions are evaluated using F1 between the predicted and expected answers.

# %%
# Import necessery libraries 
import numpy as np
import pandas as pd
import pandas_profiling
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import re
import spacy
from spacy.lang.en import English
import nltk
from nltk.corpus import stopwords
STOPWORDS = stopwords.words('english')
from spellchecker import SpellChecker
sns.set_style('darkgrid')
from datetime import datetime,time
# Ignore jupyter notebook warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# Common classification algorithms
from sklearn.dummy import DummyClassifier
from sklearn.naive_bayes import GaussianNB, MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier, VotingClassifier
from sklearn.neural_network import MLPClassifier

# %%
# Other pre-processing and evaluation tools needed
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.datasets import fetch_openml
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler, PolynomialFeatures, FunctionTransformer
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV, cross_val_score, learning_curve
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, f1_score
from sklearn.pipeline import make_pipeline
from sklearn.decomposition import PCA, KernelPCA
from sklearn.manifold import Isomap, LocallyLinearEmbedding, MDS, SpectralEmbedding, TSNE

# %%
# Import raw data into notebook as DataFrame
raw_train = pd.read_csv('data/train.csv')
raw_test = pd.read_csv('data/test.csv')

# To explore the data we'll make a copy
df_train = raw_train.copy(deep=True)
df_test = raw_test.copy(deep=True)

# Passing their reference to a list will make it easy to clean both at the same time
datasets = [df_train, df_test]

# %%
df_train.profile_report()
# Out:
# ...
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.9.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2020-10-20 16:06:22.771549&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
df_test.profile_report()
# Out:
# ...
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.9.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2020-10-20 16:06:29.771992&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
print(f'Train data shape: {df_train.shape}') 
print(f'Test data shape: {df_test.shape}')
# Out:
# Train data shape: (7613, 5)
# Test data shape: (3263, 4)

# %%
display(df_train.dtypes.value_counts())
# Out:
# object    3
# int64     2
# dtype: int64

# %%
display(df_test.dtypes.value_counts())
# Out:
# object    3
# int64     1
# dtype: int64

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7613 entries, 0 to 7612
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        7613 non-null   int64
#  1   keyword   7552 non-null   object
#  2   location  5080 non-null   object
#  3   text      7613 non-null   object
#  4   target    7613 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 297.5+ KB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3263 entries, 0 to 3262
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        3263 non-null   int64
#  1   keyword   3237 non-null   object
#  2   location  2158 non-null   object
#  3   text      3263 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 102.1+ KB

# %%
df_train.isnull().sum()
# Out:
# id             0
# keyword       61
# location    2533
# text           0
# target         0
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# id             0
# keyword       26
# location    1105
# text           0
# dtype: int64

# %%
df_train.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df_test.head()
# Out:
#    id keyword location                                               text
# 0   0     NaN      NaN                 Just happened a terrible car crash
# 1   2     NaN      NaN  Heard about #earthquake is different cities, s...
# 2   3     NaN      NaN  there is a forest fire at spot pond, geese are...
# 3   9     NaN      NaN           Apocalypse lighting. #Spokane #wildfires
# 4  11     NaN      NaN      Typhoon Soudelor kills 28 in China and Taiwan

# %%
df_train.describe()
# Out:
#                  id      target
# count   7613.000000  7613.00000
# mean    5441.934848     0.42966
# std     3137.116090     0.49506
# min        1.000000     0.00000
# 25%     2734.000000     0.00000
# 50%     5408.000000     0.00000
# 75%     8146.000000     1.00000
# max    10873.000000     1.00000

# %%
print('Real\n')
for i in df_train[df_train.target==1].text[:5].values:
    print(i)
print('')
print('Fake\n')
for i in df_train[df_train.target==0].text[:5].values:
    print(i)
# Out:
# Real
#
# Our Deeds are the Reason of this #earthquake May ALLAH Forgive us all
# Forest fire near La Ronge Sask. Canada
# All residents asked to 'shelter in place' are being notified by officers. No other evacuation or shelter in place orders are expected
# 13,000 people receive #wildfires evacuation orders in California
# Just got sent this photo from Ruby #Alaska as smoke from #wildfires pours into a school
#
# Fake
#
# What's up man?
# I love fruits
# Summer is lovely
# My car is so fast
# What a goooooooaaaaaal!!!!!!

# %%
sns.barplot(x=df_train['target'].value_counts().index, y=df_train['target'].value_counts() );

# %%
sns.barplot(y=df_train['keyword'].value_counts()[:20].index,x=df_train['keyword'].value_counts()[:20],orient='h');

# %%
sns.barplot(y=df_train['location'].value_counts()[:10].index,x=df_train['location'].value_counts()[:10],orient='h');

# %%
# Character length in both tweets is similar, slightly longer for disaster tweets
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(10,6))
sns.distplot(df_train[df_train['target']==0]['text'].apply(lambda x: len(x)), ax=ax1)
ax1.axvline(np.mean(df_train[df_train['target']==0]['text'].apply(lambda x: len(x))), color='g', linestyle='--')
sns.distplot(df_train[df_train['target']==1]['text'].apply(lambda x: len(x)), color='r', ax=ax2)
ax2.axvline(np.mean(df_train[df_train['target']==1]['text'].apply(lambda x: len(x))), color='g', linestyle='--')
fig.suptitle('Characters in Tweets')
ax1.set_title('Not Disaster')
ax2.set_title('Disaster')
plt.show()

# %%
# Very similar word count in both
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(10,6))
sns.distplot(df_train[df_train['target']==0]['text'].apply(lambda x: len(str(x).split(' '))), ax=ax1)
ax1.axvline(np.mean(df_train[df_train['target']==0]['text'].apply(lambda x: len(str(x).split(' ')))), color='g', linestyle='--')
sns.distplot(df_train[df_train['target']==1]['text'].apply(lambda x: len(str(x).split(' '))), color='r', ax=ax2)
ax2.axvline(np.mean(df_train[df_train['target']==1]['text'].apply(lambda x: len(str(x).split(' ')))), color='g', linestyle='--')
fig.suptitle('Word count in Tweets')
ax1.set_title('Not Disaster')
ax2.set_title('Disaster')
plt.show()

# %%
def word_length(text):
    l1 = str(text).split(' ')
    l2 = [len(word) for word in l1]
    return np.mean(l2)

# %%
# Very similar average word length in both
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(10,6))
sns.distplot(df_train[df_train['target']==0]['text'].apply(word_length), ax=ax1)
ax1.axvline(np.mean(df_train[df_train['target']==0]['text'].apply(word_length)), color='g', linestyle='--')
sns.distplot(df_train[df_train['target']==1]['text'].apply(word_length), color='r', ax=ax2)
ax2.axvline(np.mean(df_train[df_train['target']==1]['text'].apply(word_length)), color='g', linestyle='--')
fig.suptitle('Average word length in tweets')
ax1.set_title('Not Disaster')
ax2.set_title('Disaster')
ax1.set(xlim=(0,20))
ax2.set(xlim=(0,20))
plt.show()

# %%
import string
def count_punc(text):
    count=0
    l1 = str(text).split()
    for token in l1:
        if token in string.punctuation:
            count +=1
    return count

# %%
# Very similar punctuation count in both
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(10,6))
sns.distplot(df_train[df_train['target']==0]['text'].apply(lambda x: count_punc(x)), ax=ax1)
ax1.axvline(np.mean(df_train[df_train['target']==0]['text'].apply(lambda x: count_punc(x))), color='g', linestyle='--')
sns.distplot(df_train[df_train['target']==1]['text'].apply(lambda x: count_punc(x)), color='r', ax=ax2)
ax2.axvline(np.mean(df_train[df_train['target']==1]['text'].apply(lambda x: count_punc(x))), color='g', linestyle='--')
fig.suptitle('Number of punctuation in tweets')
ax1.set_title('Not Disaster')
ax2.set_title('Disaster')
ax1.set(xlim=(0,3))
ax2.set(xlim=(0,3))
plt.show()

# %%
# More stop words in non-disaster tweets
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(10,6))
sns.distplot(df_train[df_train['target']==0]['text'].apply(lambda x: len([w for w in str(x).lower().split() if w in STOPWORDS])), ax=ax1)
ax1.axvline(np.mean(df_train[df_train['target']==0]['text'].apply(lambda x: len([w for w in str(x).lower().split() if w in STOPWORDS]))), color='g', linestyle='--')
sns.distplot(df_train[df_train['target']==1]['text'].apply(lambda x: len([w for w in str(x).lower().split() if w in STOPWORDS])), color='r', ax=ax2)
ax2.axvline(np.mean(df_train[df_train['target']==1]['text'].apply(lambda x: len([w for w in str(x).lower().split() if w in STOPWORDS]))), color='g', linestyle='--')
fig.suptitle('Number of stop words in tweets')
ax1.set_title('Not Disaster')
ax2.set_title('Disaster')
plt.show()

# %%
t1 =datetime.now()

# %%
# Out:
# datetime.timedelta(seconds=11, microseconds=24643)

# %%
def save_csv(y_pred, file_name):
    sub = pd.DataFrame({'id':df_test['id'], 'target':y_pred})
    display(sub)
    sub.to_csv(f'submissions/{file_name}', index=False)

# %%
X=df_train['text']
y=df_train['target']

# %%
# pipe = make_pipeline(CountVectorizer(), MultinomialNB())

# %%
# pipe.named_steps

# %%
# param_grid = [{
#     'countvectorizer__stop_words':[None],
#     'countvectorizer__ngram_range':[(1,1)],
#     'countvectorizer__max_df':[0.4,0.5,0.6,],
#     'countvectorizer__min_df':[2],
#     'countvectorizer__max_features':[3000,4000,5000,6000, 10000],
#     'multinomialnb__alpha':[5,7,10,15,20,30],
# }]

# %%
# clf = GridSearchCV(pipe, param_grid=param_grid, n_jobs=-1, cv=4, verbose=1)
# clf.fit(X, y)

# %%
# print(clf.best_params_)
# print(clf.best_estimator_)
# print(clf.best_score_)

# %%
# save_csv(clf.best_estimator_.predict(df_test['text']),'count_vext2.csv')

# %%
# pipe = make_pipeline(TfidfVectorizer(), MultinomialNB())
# pipe.named_steps

# %%
# param_grid = [{
#     'tfidfvectorizer__stop_words':[None, 'english'],
#     'tfidfvectorizer__ngram_range':[(1,1),(2,2),(1,2)],
#     'tfidfvectorizer__max_df':np.arange(0.3,1.01,0.05),
#     'tfidfvectorizer__min_df':[1,2,3],
#     'tfidfvectorizer__max_features':range(1000,10001,1000),
#     'multinomialnb__alpha':range(0,30,2),
# }]

# %%
# clf = GridSearchCV(pipe, param_grid=param_grid, n_jobs=-1, cv=4, verbose=1)
# clf.fit(X, y)

# %%
# print(clf.best_params_)
# print(clf.best_estimator_)
# print(clf.best_score_)

# %%
# pipe= make_pipeline(TfidfVectorizer(max_df=0.3, max_features=1000), MultinomialNB(alpha=0))

# %%
# pipe.fit(X,y)

# %%
# save_csv(pipe.predict(df_test['text']),'tfidf_vext.csv')

# %%
re.sub("(https|http)\S+", "", "Visit https://www.youtube.com/watch?v=E3ibYcsJEOo for the latest dutch song.")
# Out:
# 'Visit  for the latest dutch song.'

# %%
df_train[df_train.duplicated(subset=['text'], keep=False)]
# Out:
#          id     keyword        location  \
# 40       59      ablaze  Live On Webcam
# 48       68      ablaze  Live On Webcam
# 106     156  aftershock              US
# 115     165  aftershock              US
# 118     171  aftershock     Switzerland
# ...     ...         ...             ...
# 7600  10855         NaN             NaN
# 7607  10867         NaN             NaN
# 7609  10870         NaN             NaN
# 7610  10871         NaN             NaN
# 7611  10872         NaN             NaN
#
#                                                    text  target
# 40    Check these out: http://t.co/rOI2NSmEJJ http:/...       0
# 48    Check these out: http://t.co/rOI2NSmEJJ http:/...       0
# 106   320 [IR] ICEMOON [AFTERSHOCK] | http://t.co/vA...       0
# 115   320 [IR] ICEMOON [AFTERSHOCK] | http://t.co/vA...       0
# 118   320 [IR] ICEMOON [AFTERSHOCK] | http://t.co/TH...       0
# ...                                                 ...     ...
# ...

# %%
spell = SpellChecker()
def correct_spellings(text):
    corrected_text = []
    misspelled_words = spell.unknown(text.split())
    for word in text.split():
        if word in misspelled_words:
            corrected_text.append(spell.correction(word))
        else:
            corrected_text.append(word)
    return " ".join(corrected_text)

# %%
def clean_tweet(tweet):
    # Make tweet lowercase
    tweet = tweet.lower()
    # Remove text in square brackets
    tweet = re.sub('\[.*?\]', '', tweet)
    # Remove URLs
    tweet = re.sub(r'https?://\S+|www\.\S+', '', tweet)
    #tweet = re.sub(r'https?://www.', '', tweet)
    #tweet = re.sub(r'\.com\S+', '', tweet)
    # Remove Punctuation
    tweet = re.sub('[%s]' % re.escape(string.punctuation), '', tweet)
    # Remove HTML Tags
    tweet = re.sub(r'<.*?>', '', tweet)
    # Remove newline & text containing numbers
    tweet = re.sub('\n', '', tweet)
    tweet = re.sub('\w*\d\w*', '', tweet)
    # Remove Emojis
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    tweet = emoji_pattern.sub(r'', tweet)
    # Remove_stopwords
    tweet = ' '.join([w for w in tweet.split() if w not in STOPWORDS])
    # Correct spelling
    tweet = correct_spellings(tweet)
    # Return Tweet
    return tweet

# %%
def cleaner(series):
    return series.apply(lambda x: clean_tweet(x))

# %%
# Create Function Transformer
series_cleaner = FunctionTransformer(cleaner)

# %%
pipe = make_pipeline(series_cleaner, CountVectorizer(), MultinomialNB())

# %%
start = datetime.now()
print(np.mean(cross_val_score(pipe, df_train['text'], df_train['target'], cv=4, n_jobs=-1 )))
end = datetime.now()
print(end - start)
# Out:
# 0.7215268792750942
# 7:34:29.930990

# %%
0.7215268792750942 7:34:29.930990

# %%
example = "Helo, the as is I'm dyeing, this song tho: https://www.youtube.com/watch?v=E3ibYcsJEOo lattest dutch song! #drillking 😔😔"

# %%
print(example)
print(clean_tweet(example))
# Out:
# Helo, I'm dyeing, this song tho: https://www.youtube.com/watch?v=E3ibYcsJEOo lattest dutch song! #drillking 😔😔
# help im dyeing this song tho latest dutch song drilling

# %%
# X_train = df_train['text'].apply(lambda x: clean_tweet(x))

# %%
# X_test = df_test['text'].apply(lambda x: clean_tweet(x))

# %%
y = df_train['target']

# %%
t1 = nltk.tokenize.WhitespaceTokenizer()
t2 = nltk.tokenize.TreebankWordTokenizer()
t3 = nltk.tokenize.WordPunctTokenizer()
t4 = nltk.tokenize.RegexpTokenizer(r'\w+')

# %%
from nltk.tokenize import WhitespaceTokenizer

# %%
new = df_train['text'].apply(lambda x: t2.tokenize(x)).apply(lambda x: remove_stopwords(x)).apply(lambda x: ' '.join(x))

# %%
new

# %%
pipe = make_pipeline(CountVectorizer(), MultinomialNB())

# %%
np.mean(cross_val_score(pipe, new, df_train['target'], cv=4, n_jobs=-1 ))

# %%
np.mean(cross_val_score(pipe, new, df_train['target'], cv=4, n_jobs=-1 ))

# %%
np.mean(cross_val_score(pipe, new, df_train['target'], cv=4, n_jobs=-1 ))

# %%
np.mean(cross_val_score(pipe, new, df_train['target'], cv=4, n_jobs=-1 ))

# %%
np.mean(cross_val_score(pipe, new, df_train['target'], cv=4, n_jobs=-1 ))

# %%
pipe = make_pipeline(CountVectorizer(), MultinomialNB())

# %%
np.mean(cross_val_score(pipe, X_train, y, cv=3, n_jobs=-1))

# %%
np.mean(cross_val_score(pipe, X_train, y, cv=3, n_jobs=-1))

# %%
from nltk.stem.porter import PorterStemmer
stem = PorterStemmer()
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
' '.join(word_tokenize("You're my friend"))

# %%
models = [DummyClassifier(), GaussianNB(), KNeighborsClassifier(), LinearSVC(), SVC(), LogisticRegression(), 
          DecisionTreeClassifier(), RandomForestClassifier(), ExtraTreesClassifier(), MLPClassifier(), MultinomialNB()]

# %%
model_names = [model.__class__.__name__ for model in models]

# %%
train_scores, cv_scores = [],[]

# %%
# print('Model\ntrain_f1_score\ncv_f1_score\n')
# for model in models:
#     print(model.__class__.__name__)
#     model.fit(X,y)
#     train_score = f1_score(y, model.predict(X))
#     train_scores.append(train_score)
#     print(train_score)
#     cv_score = np.mean(cross_val_score(model, X, y, cv=4, scoring='f1', n_jobs=-1))
#     cv_scores.append(cv_score)
#     print(cv_score)
#     print("")

# %%
# scores = pd.DataFrame({'model':model_names, 'train_scores':train_scores, 'cv_scores':cv_scores}).set_index('model')
# scores.to_csv('scores.csv')
# scores

# %%
pd.read_csv('scores.csv')

# %%
#save_csv(y_pred= MultinomialNB().fit(X,y).predict(count_vectorizer.transform(df_test['text'])), file_name = 'count_vect1.csv')

# %%
# Prediction made using only pre-processing done by default CountVectorizer() model in scikit learn which uses bag-of-words. 
print('Default CountVectorizer()')
print('CV_Score: 0.69154')
print('Kaggle test submission: 0.79619\n')

# Prediction made using tuned hyperparameters of CountVectorizer() and MultinomialNB(), found using GridSearchCV on pipeline.
print('CountVectorizer(max_df=0.4, max_features=6000, min_df=2) + MultinomialNB(alpha=5)')
print('CV_Score: 0.75371')
print('Kaggle test submission: 0.79221\n')

# Prediction made using tuned hyperparameters of TfidfVectorizer() and MultinomialNB(), found using GridSearchCV on pipeline.
print('TfidfVectorizer(max_df=0.3, max_features=1000) + MultinomialNB(alpha=0)')
print('CV_Score: N/A')
print('Kaggle test submission: 0.77903\n')

# %% [markdown]
# Most of the models do better than just random guessing which would result in accuracy of 0.5, notably GaussianNB, Linear SVC, MLP all have an accuracy higher than 0.6. However, MultinomialNB does significantly better than these with an accuarcy close to 0.7! This algortith is known to well with text data & word count vectors. Hence we will try to pre-process and text in such a away that results in the results in the highest cross validation f1 score for tis model.
